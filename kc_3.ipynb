# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def main():
    # Get Indices of total farm output, data from 1948 - 2019
    df = pd.read_csv("Indices_of_farm_output.csv")
    print()
    print()
    get_egg_difference(df)
    print()
    print()
    get_eggs_average(df)
    print()
    print()
    get_eggs_total(df)
    print()
    print()
    print()
    get_total(df)
    print()
    print()
    side_by_side_plots()
    #get_total(df)

def get_eggs_total(df):
    # Get Indices of total egg output, data from 1948 - 2019
    poultry_eggs = df[(df["Attribute"] == "Livestock and products output: Poultry and eggs")]
    #avg_value = round(df.Value.mean(),0)
    print(poultry_eggs)
    print()
    plt.xlabel('Yearly change', size=16)
    plt.ylabel('Farm output value', size=16)
    plt.title(f'The avg. egg production 1948 - 2019 is: {avg_value}', size=18)
    #print(f"The average value of egg production from 1948 - 2019 is: {avg_value}")
    sns.scatterplot(x=total_Agri_Out['Year'],
            y=total_Agri_Out['Value'])
    return plt.show()

def get_eggs_average(df):
    poultry_eggs = df[(df["Attribute"] == "Livestock and products output: Poultry and eggs")]
    avg_value = round(df.Value.mean(),0)
    return print(f"The average value of egg production from 1948 - 2019 is: {avg_value}")

def get_egg_difference(df):
    poultry_eggs = df[(df["Attribute"] == "Livestock and products output: Poultry and eggs")]
    poultry_eggs = poultry_eggs.reset_index(drop=True)
    #select_start = df.loc[df['Year'] == '1948']
    #select_end = df.loc[df['Year'] == '2019']
    onerow = poultry_eggs[poultry_eggs['Year'] == '1948']
    beg = poultry_eggs.iloc[0]
    end = poultry_eggs.iloc[70]
    data = (beg, end )
    
    df_year = pd.DataFrame(data)
    df_year = df_year.reset_index(drop=True)
    #Add new column with difference
    df_year['ProdDiff'] = df_year['Value'].diff()
    
    return print(df_year)

def get_total(df):
    df.head()
    print(df)

    sns.scatterplot(x=df['Year'],
                    y=df['Value'])
    return plt.show

def side_by_side_plots():
    # Create figure and multiple plots
    fig, axes = plt.subplots(nrows=1, ncols=2)

    # Auto adjust
    plt.tight_layout()

    # Display
    return plt.show()
    
main()
# Out:
#    Year                                        Attribute     Value  ProdDiff
# 0  1948  Livestock and products output: Poultry and eggs  0.129304       NaN
# 1  2019  Livestock and products output: Poultry and eggs  1.091174   0.96187
#
#
# The average value of egg production from 1948 - 2019 is: 1.0
#
#
#       Year                                        Attribute     Value
# 4     1948  Livestock and products output: Poultry and eggs  0.129304
# 34    1949  Livestock and products output: Poultry and eggs  0.148074
# 64    1950  Livestock and products output: Poultry and eggs  0.158971
# 94    1951  Livestock and products output: Poultry and eggs  0.170449
# 124   1953  Livestock and products output: Poultry and eggs  0.178877
# ...    ...                                              ...       ...
# 1984  2015  Livestock and products output: Poultry and eggs  1.000000
# 2014  2016  Livestock and products output: Poultry and eggs  1.019666
# 2044  2017  Livestock and products output: Poultry and eggs  1.044365
# 2074  2018  Livestock and products output: Poultry and eggs  1.069143
# 2104  2019  Livestock and products output: Poultry and eggs  1.091174
#
# [71 rows x 3 columns]
#       Year                                        Attribute     Value
# 0     1948                        Total agricultural output  0.362833
# 1     1948          Livestock and products output: Total 1/  0.437903
# 2     1948      Livestock and products output: Meat animals  0.562957
# 3     1948             Livestock and products output: Dairy  0.448529
# 4     1948  Livestock and products output: Poultry and eggs  0.129304
# ...    ...                                              ...       ...
# 2125  2019         Intermediate inputs: Fertilizer and lime  0.676226
# 2126  2019                  Intermediate inputs: Pesticides  1.044259
# 2127  2019          Intermediate inputs: Purchased services  0.991751
# 2128  2019          Intermediate inputs: Other intermediate  0.884914
# 2129  2019                  Total factor productivity (TFP)  1.009214
#
# [2130 rows x 3 columns]
